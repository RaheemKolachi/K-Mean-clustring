# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
x=pd.read_csv("X_train.csv")
xtest = pd.read_csv("X_test.csv")
y=pd.read_csv("y_train.csv")
ytest=pd.read_csv("y_test.csv")

# %%
from sklearn.cluster import KMeans

data = list(zip(x, y))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(x)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
features = list(x.columns)

# %%
data = x[features]
from sklearn.decomposition import PCA

# %%
clustering_kmeans = KMeans(n_clusters=5)
data['clusters'] = clustering_kmeans.fit_predict(x)

# %%
pca_num_components = 2
import seaborn as sns

reduced_data = PCA(n_components=pca_num_components).fit_transform(data)
results = pd.DataFrame(reduced_data,columns=['pca1','pca2'])


sns.scatterplot(x="pca1", y="pca2", hue=data['clusters'], data=results)
plt.scatter(kmeans.cluster_centers_[:5, 0], kmeans.cluster_centers_[:5, 1], s=300, c='black', label = "centeriod")
plt.title('5-means Clustering with 2 dimensions')
plt.show()
